# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, recall_score, f1_score, confusion_matrix
from sklearn.neighbors import LocalOutlierFactor
from sklearn.model_selection import StratifiedKFold, cross_validate

# %%
df = pd.read_csv('creditcard.csv')
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
print(f'\nThe dataset contains a total number of {df.shape[0]} observations and {df.shape[1]} columns')

target = 'Class'

features = [c for c in df.columns if c not in [target]]
print(f'\nThe dataset contains {len(features)} features')
# Out:
# The dataset contains a total number of 284807 observations and 31 columns
#
# The dataset contains 30 features

# %% [markdown]
# ### Variable Data types

# %%
# df.info()
# df.isnull().sum()
print(f'\nThe datatypes are all floats with the exception of Class, and there are no null values which is great')
# Out:
# The datatypes are all floats with the exception of Class, and there are no null values which is great

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### Class Distribution

# %% [markdown]
# This is a binary classification problem and as such let's see the Class distribution of each of the class.
# - 0 - Normal transaction
# - 1 - Fraudulent transaction

# %%
# df['Class'].value_counts()

plt.figure(figsize=(7,4))
plt.title('Target Distribution', fontsize=20)
sns.countplot(df['Class'])

# %% [markdown]
# #### Let's see the percentage of each class

# %%
# Count the total number of Normal trabsaction
Count_Normal_transaction = len(df[df["Class"]==0]) 

# Count fraudulent transaction
Count_Fraud_transaction = len(df[df["Class"]==1])

Percentage_of_Normal_transaction = Count_Normal_transaction/(Count_Normal_transaction+Count_Fraud_transaction)
print("Percentage of normal transacation is",Percentage_of_Normal_transaction*100)

Percentage_of_Fraud_transaction= Count_Fraud_transaction/(Count_Normal_transaction+Count_Fraud_transaction)
print(f'\nPercentage of fraudulent transacation, {Percentage_of_Fraud_transaction*100}')
# Out:
# Percentage of normal transacation is 99.82725143693798
#
# Percentage of fraudulent transacation, 0.1727485630620034

# %% [markdown]
# ####  Let's create dataframe for both Normal and Fraudulent transaction

# %%
# Fraudulent Transaction
fraud = df[df['Class']==1]

# Normal Transaction
Normal = df[df['Class']==0]

print(Normal.shape, fraud.shape)
# Out:
# (284315, 31) (492, 31)

# %% [markdown]
# #### Let's check the summary of both transaction classes with Time and Amount

# %%
Normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# From the table above, we can see there's a high variability b/w the data points.

# %% [markdown]
# #### Let's check the distribution of datapoint on both dataframe

# %%
plt.figure(figsize=(15,9))

plt.subplot(2,2,1)
fraud['Amount'].hist(bins=10)
plt.title('Distribution of Amount in Fraudulent Transaction', size=13)

#plot the amount feature
plt.subplot(2, 2, 2)
Normal['Amount'].hist(bins=10)
plt.title('Distribution of Amount in Normal Transaction', fontsize=13)
# Out:
# Text(0.5, 1.0, 'Distribution of Amount in Normal Transaction')

# %% [markdown]
# From the histograms above, the distribution of data point seems not to be clear. We will reduce the amount to 2500, since it seems all normal transactions are within that range.

# %%
plt.figure(figsize=(15,9))

plt.subplot(2,2,1)
fraud[fraud['Amount']<=2500]['Amount'].hist(bins=10)
plt.title('Distribution of Amount in Fraudulent Transaction', size=13)

#plot the amount feature
plt.subplot(2, 2, 2)
Normal[Normal['Amount']<=2500]['Amount'].hist(bins=10)
plt.title('Distribution of Amount in Normal Transaction', fontsize=13)
# Out:
# Text(0.5, 1.0, 'Distribution of Amount in Normal Transaction')

# %%
plt.figure(figsize=(15,9))

plt.subplot(2,2,1)
fraud['Time'].hist(bins=50)
plt.title('Distribution of Time in Fraudulent Transaction', size=13)

#plot the amount feature
plt.subplot(2, 2, 2)
Normal['Time'].hist(bins=50)
plt.title('Distribution of Time in Normal Transaction', fontsize=13)
# Out:
# Text(0.5, 1.0, 'Distribution of Time in Normal Transaction')

# %% [markdown]
# From the graph above, the distribution of time in fraudulent transaction looks abit uniformly distributed while the distribution of time with Normal distribution shows two data peaks indicating a bimodal histogram

# %% [markdown]
# #### Let's Compare the distribution of time in both Fraudulent and Normal transactions

# %%
timedelta = pd.to_timedelta(df['Time'], unit='s')
df['Time_hour'] = (timedelta.dt.components.hours).astype(int)

plt.figure(figsize=(12,5))
sns.distplot(df[df['Class'] == 0]["Time_hour"], color='g')
sns.distplot(df[df['Class'] == 1]["Time_hour"], color='r')
plt.title('Fraud and Normal Transactions by Hours', fontsize=17)
plt.xlim([-1,25])
plt.show()

# %%
# Lets check the distribution of fraudulent transaction data point and normal transaction data point
df.groupby('Class').hist(figsize=(17, 12))
# Out:
# Class
# 0    [[AxesSubplot(0.125,0.779333;0.103333x0.100667...
# 1    [[AxesSubplot(0.125,0.779333;0.103333x0.100667...
# dtype: object

# %% [markdown]
# #### Let's check if there is any correlation between the features

# %%
plt.figure(figsize=(15,9))
sns.heatmap(df.corr(), vmin=-1, vmax=1, center=0, cmap= 'coolwarm', linewidths=1, linecolor='black')
plt.title('Credit Card Transactions features correlation plot (Pearson)', size=15)
# Out:
# Text(0.5, 1, 'Credit Card Transactions features correlation plot (Pearson)')

# %% [markdown]
# From the correlation matrix heat map above, the V features do not have any correlation with each other. However, features V1 to V18 show some form of positive and negative correlation with the class feature. Time and Amount are not correlated with class feature.

# %%
X = df.drop('Class', axis = 1)
y = df['Class']

# Split dataset into 80% training and 20 testing
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
# Create outliers
outliers = fraud.drop('Class', axis = 1)

# Create the inliers
inliers = Normal.drop('Class', axis = 1)

# threshold for use 
Outlier_fraction = len(fraud)/float(len(Normal))

# %% [markdown]
# ### Modelling

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor

# define random states
state = 1

# define outlier detection tools to be compared
classifiers = {
    "Isolation Forest": IsolationForest(max_samples=len(X),
                                        contamination=Outlier_fraction,
                                        random_state=state),
    "Local Outlier Factor": LocalOutlierFactor(
        n_neighbors=20,
        contamination=Outlier_fraction)}

# %%
# Fit the model
plt.figure(figsize=(9, 7))
n_outliers = len(fraud)


for i, (clf_name, clf) in enumerate(classifiers.items()):
    
    # fit the data and tag outliers
    if clf_name == "Local Outlier Factor":
        y_pred = clf.fit_predict(X)
        scores_pred = clf.negative_outlier_factor_
    else:
        clf.fit(X)
        scores_pred = clf.decision_function(X)
        y_pred = clf.predict(X)
    
    # Reshape the prediction values to 0 for valid, 1 for fraud. 
    y_pred[y_pred == 1] = 0
    y_pred[y_pred == -1] = 1
    
    n_errors = (y_pred != Y).sum()
    
    # Run classification metrics
    print('{}: {}'.format(clf_name, n_errors))
    print(accuracy_score(Y, y_pred))
    print(classification_report(Y, y_pred))
# Out:
# Isolation Forest: 679
# 0.9976159293837581
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    284315
#            1       0.31      0.31      0.31       492
#
#     accuracy                           1.00    284807
#    macro avg       0.65      0.65      0.65    284807
# weighted avg       1.00      1.00      1.00    284807
#
# Local Outlier Factor: 935
# 0.9967170750718908
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    284315
#            1       0.05      0.05      0.05       492
#
#     accuracy                           1.00    284807
#    macro avg       0.52      0.52      0.52    284807
# weighted avg       1.00      1.00      1.00    284807
